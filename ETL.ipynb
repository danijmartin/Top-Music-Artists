# %%
#dependicies
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data

# %%
file= 'Resources/artists.csv'

# %%
artists_df = pd.read_csv(file)
#print(artists_df.columns)
# Out:
# C:\Users\slamd\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2,4,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
new_artists_df = artists_df.drop(columns=["mbid", "artist_lastfm", "country_lastfm", "tags_mb","tags_lastfm", "scrobbles_lastfm", "ambiguous_artist"]).head(50)
new_artists_df
# Out:
#                 artist_mb      country_mb  listeners_lastfm
# 0                Coldplay  United Kingdom         5381567.0
# 1               Radiohead  United Kingdom         4732528.0
# 2   Red Hot Chili Peppers   United States         4620835.0
# 3                 Rihanna   United States         4558193.0
# 4                  Eminem   United States         4517997.0
# 5             The Killers   United States         4428868.0
# 6              Kanye West   United States         4390502.0
# 7                 Nirvana   United States         4272894.0
# 8                    Muse  United Kingdom         4089612.0
# 9                   Queen  United Kingdom         4023379.0
# 10           Foo Fighters   United States         4005236.0
# 11            Linkin Park   United States         3978390.0
# 12              Lady Gaga   United States         3820581.0
# 13     The Rolling Stones  United Kingdom         3798330.0
# 14              Daft Punk          France         3782404.0
# 15              Green Day   United States         3738772.0
# 16             Katy Perry   United States         3733134.0
# 17            The Beatles  United Kingdom         3674017.0
# 18                  Oasis  United Kingdom         3592076.0
# 19               Gorillaz  United Kingdom         3577998.0
# 20                Beyoncé   United States         3554615.0
# 21        Michael Jackson   United States         3546966.0
# 22               Maroon 5   United States         3507447.0
# 23         Arctic Monkeys  United Kingdom         3501680.0
# 24       System of a Down   United States         3497648.0
# 25                     U2         Ireland         3487345.0
# 26          Kings of Leon   United States         3437638.0
# 27                  Drake          Canada         3379644.0
# 28            David Bowie  United Kingdom         3354711.0
# 29    The Black Eyed Peas   United States         3346410.0
# 30            The Strokes   United States         3262563.0
# 31         Britney Spears   United States         3255085.0
# 32          Guns N’ Roses   United States         3241492.0
# 33        Franz Ferdinand  United Kingdom         3203026.0
# 34              The Doors   United States         3189868.0
# 35                  JAY-Z   United States         3169635.0
# 36                Madonna   United States         3102727.0
# 37             Pink Floyd  United Kingdom         3081313.0
# 38                 Weezer   United States         3050491.0
# 39            Snow Patrol  United Kingdom         2982390.0
# 40              blink‐182   United States         2976416.0
# 41      The White Stripes   United States         2956612.0
# 42               The Cure  United Kingdom         2932819.0
# 43           Led Zeppelin  United Kingdom         2930957.0
# 44                   Beck   United States         2918241.0
# 45              Aerosmith   United States         2904687.0
# 46          The Offspring   United States         2900065.0
# 47              Metallica   United States         2894382.0
# 48                 R.E.M.   United States         2886482.0
# 49                   Blur  United Kingdom         2872022.0

# %%
client_id = {spotify client id}
client_secret = {spotify secret id}
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API
name = "Coldplay" #chosen artist
result = sp.search(name) #search query
result['tracks']['items'][0]['artists']
# Out:
#   File "<ipython-input-5-83db861415fe>", line 1
#     client_id = {spotify client id}
#                          ^
# SyntaxError: invalid syntax
